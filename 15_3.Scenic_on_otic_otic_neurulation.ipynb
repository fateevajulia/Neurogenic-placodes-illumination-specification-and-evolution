# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import loompy as lp

# %%
#adata.write('/home/julia/data/placodes/h5ad/11_normalized.h5ad')

# %%
adata=sc.read_h5ad('/home/julia/data/placodes/h5ad/11_qc.h5ad')
# Out:
# /home/julia/miniconda3/envs/scenicplus/lib/python3.8/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
#adata=sc.read_h5ad('/home/julia/data/placodes/h5ad/11_normalized.h5ad')

# %%
adata.obs_names_make_unique()

# %%
#adata=sc.read_h5ad('/home/julia/data/placodes/noutbooks/h5ad_files/14_06_ALL_7_datasets_qc.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 62269 × 25865
#     obs: 'plate', 'day', 'location', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'doublet_score', 'predicted_doublet', 'batch'
#     layers: 'counts'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 62269 × 25865
#     obs: 'plate', 'day', 'location', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'doublet_score', 'predicted_doublet', 'batch'
#     layers: 'counts'

# %%
adata_placodes=sc.read_h5ad('../otic_normal_15_08.h5ad')
adata_placodes=adata_placodes.raw.to_adata()

# %%
adata_placodes.obs_names_make_unique()

# %%
cell=adata_placodes.obs_names
adata[cell]
# Out:
# View of AnnData object with n_obs × n_vars = 6028 × 25865
#     obs: 'plate', 'day', 'location', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'doublet_score', 'predicted_doublet', 'batch'
#     layers: 'counts'

# %%
adata_new=adata[cell]

# %%
adata_new
# Out:
# View of AnnData object with n_obs × n_vars = 6028 × 25865
#     obs: 'plate', 'day', 'location', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'doublet_score', 'predicted_doublet', 'batch'
#     layers: 'counts'

# %%
adata_new.write('adata_placodes.h5ad')

# %%
adata=adata_new

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 6028 × 25865
#     obs: 'plate', 'day', 'location', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'doublet_score', 'predicted_doublet', 'batch'
#     layers: 'counts'

# %%
# path to unfiltered loom file (this will be created in the optional steps below)
f_loom_path_unfilt = "placods_unfiltered.loom" # test dataset, n=500 cells

# # path to loom file with basic filtering applied (this will be created in the "initial filtering" step below). Optional.
f_loom_path_scenic = "placodes_filtered_scenic.loom"

# path to anndata object, which will be updated to store Scanpy results as they are generated below
#f_anndata_path = "anndata.h5ad"

# path to pyscenic output
f_pyscenic_output = "placodes_pyscenic_output.loom"

# loom output, generated from a combination of Scanpy and pySCENIC results:
f_final_loom = 'placodes_scenic_integrated-output.loom'

# %%
adata.obs_names
# Out:
# Index(['ACATCCCGTTGACTAC-1', 'AGGATCTAGTGTTCAC-1', 'CACATGAAGTCTAACC-1',
#        'CATTGCCCAGCGTATT-1', 'CTTCTCTAGGCACCAA-1', 'AAACCCACATCGGTTA-1',
#        'AAACGCTCACCAACAT-1', 'AAAGGTATCGAATGCT-1', 'AAAGTGAGTCATTCCC-1',
#        'AACAAAGGTGTAAACA-1',
#        ...
#        'TTGGGATAGAGAGTTT-1-3', 'TTGGGATAGCTCGCAC-1-3', 'TTGGTTTGTTCCCAAA-1-3',
#        'TTGTGTTGTGGAGGTT-1-3', 'TTGTGTTGTTGACGGA-1-3', 'TTGTTGTGTCCGATCG-1-3',
#        'TTGTTTGGTAGCCAGA-1-3', 'TTTCACAGTAGGCTCC-1-3', 'TTTCAGTCATAGGTAA-1-3',
#        'TTTCAGTTCGTTGTAG-1-3'],
#       dtype='object', length=6028)

# %%
# path to unfiltered loom file (this will be created in the optional steps below)
f_loom_path_unfilt = "placods_unfiltered.loom" # test dataset, n=500 cells

# # path to loom file with basic filtering applied (this will be created in the "initial filtering" step below). Optional.
f_loom_path_scenic = "placodes_filtered_scenic.loom"

# path to anndata object, which will be updated to store Scanpy results as they are generated below
#f_anndata_path = "anndata.h5ad"

# path to pyscenic output
f_pyscenic_output = "placodes_pyscenic_output.loom"

# loom output, generated from a combination of Scanpy and pySCENIC results:
f_final_loom = 'placodes_scenic_integrated-output.loom'

# %%
f_tfs='/home/julia/data/Scenic_database/Mouse/TF/allTFs_mm.txt'

# %%
# !/home/julia/miniconda3/envs/scenicplus/bin/pyscenic grn /home/julia/data/placodes/ANDYs_notebboks/Placodes_tragectory/Scenic_otic/placodes_filtered_scenic.loom/Scenic_E14_mel/placodes_filtered_scenic.loom /home/julia/data/Scenic_database/Mouse/TF/allTFs_mm.txt -o adj_1.csv  --num_workers 12
# Out:
# 2025-08-15 14:08:49,603 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2025-08-15 14:08:51,587 - pyscenic.cli.pyscenic - INFO - Inferring regulatory networks.
# preparing dask client
# parsing input
# creating dask graph
# 12 partitions
# computing dask graph
# not shutting down client, client was created externally
# finished
#
# 2025-08-15 17:01:31,463 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %%
adjacencies = pd.read_csv("adj_1.csv", index_col=False)

# %%
adjacencies.head()
# Out:
#       TF         target  importance
# 0    Id1            Id2  184.725973
# 1    Id2            Id1  181.503082
# 2   Hmx1  D930028M14Rik  162.240782
# 3  Hmgb2           Cks2  148.638053
# 4    Id1            Id3  148.164058

# %%
import glob
# ranking databases
f_db_glob = "/home/julia/data/Scenic_database/Mouse/Gene_based/*feather"
f_db_names = ' '.join( glob.glob(f_db_glob) )

# %%
# motif databases
f_motif_path = "/home/julia/data/Scenic_database/Mouse/Motif2TF/motifs-v10nr_clust-nr.mgi-m0.001-o0.0.tbl"

# %%
# !/home/julia/miniconda3/envs/scenicplus/bin/pyscenic ctx adj_1.csv \
    {f_db_names} \
    --annotations_fname /home/julia/data/Scenic_database/Mouse/Motif2TF/motifs-v10nr_clust-nr.mgi-m0.001-o0.0.tbl \
    --expression_mtx_fname /home/julia/data/placodes/ANDYs_notebboks/Placodes_tragectory/Scenic_otic/placodes_filtered_scenic.loom \
    --output reg_01_07.csv \
    --mask_dropouts \
    --num_workers 20
# Out:
# 2025-08-16 20:20:24,126 - pyscenic.cli.pyscenic - INFO - Creating modules.
#
# 2025-08-16 20:20:26,659 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2025-08-16 20:20:29,181 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2025-08-16 20:20:30,547 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [True].
#
# 2025-08-16 20:21:07,392 - pyscenic.utils - INFO - Creating modules.
#
# 2025-08-16 20:23:29,167 - pyscenic.cli.pyscenic - INFO - Loading databases.
#
# 2025-08-16 20:23:29,568 - pyscenic.cli.pyscenic - INFO - Calculating regulons.
#
# 2025-08-16 20:23:29,569 - pyscenic.prune - INFO - Using 20 workers.
#
# 2025-08-16 20:23:29,569 - pyscenic.prune - INFO - Using 20 workers.
#
# 2025-08-16 20:23:32,830 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-08-16 20:23:32,830 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-08-16 20:23:32,943 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-08-16 20:23:32,943 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-08-16 20:23:32,985 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-08-16 20:23:32,985 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-08-16 20:23:33,008 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-08-16 20:23:33,008 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-08-16 20:23:33,019 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-08-16 20:23:33,019 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): database loaded in memory.
#
# 2025-08-16 20:23:33,039 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-08-16 20:23:33,039 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-08-16 20:23:33,044 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-08-16 20:23:33,044 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-08-16 20:23:33,107 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-08-16 20:23:33,107 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-08-16 20:23:33,201 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-08-16 20:23:33,201 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): database loaded in memory.
#
# 2025-08-16 20:23:33,215 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-08-16 20:23:33,215 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-08-16 20:23:33,243 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-08-16 20:23:33,243 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-08-16 20:23:33,264 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-08-16 20:23:33,264 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): database loaded in memory.
#
# 2025-08-16 20:23:33,283 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-08-16 20:23:33,283 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): database loaded in memory.
#
# 2025-08-16 20:23:33,298 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-08-16 20:23:33,298 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-08-16 20:23:33,362 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-08-16 20:23:33,362 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): database loaded in memory.
#
# 2025-08-16 20:23:33,376 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-08-16 20:23:33,376 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): database loaded in memory.
#
# 2025-08-16 20:23:33,376 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-08-16 20:23:33,376 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): database loaded in memory.
#
# 2025-08-16 20:23:33,380 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-08-16 20:23:33,380 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): database loaded in memory.
#
# 2025-08-16 20:23:33,383 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-08-16 20:23:33,383 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): database loaded in memory.
#
# 2025-08-16 20:23:33,445 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-08-16 20:23:33,445 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): database loaded in memory.
#
# 2025-08-16 20:23:34,702 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,702 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,793 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,793 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,802 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,802 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,833 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,833 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,868 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,868 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,873 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,873 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,876 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,876 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,889 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,889 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,964 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-08-16 20:23:34,964 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,005 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,005 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,018 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,018 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,040 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,040 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,043 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,043 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,104 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,104 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,200 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,200 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,249 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,249 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,308 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,308 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,316 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,316 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(10): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,326 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,326 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,339 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-08-16 20:23:35,339 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): motif annotations loaded in memory.
#
# 2025-08-16 20:23:39,930 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp748 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:40,544 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp759 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:40,890 - pyscenic.transform - WARNING - Less than 80% of the genes in Id4 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:41,226 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp760 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:41,666 - pyscenic.transform - WARNING - Less than 80% of the genes in Gpam could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:42,284 - pyscenic.transform - WARNING - Less than 80% of the genes in Ilf2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:42,406 - pyscenic.transform - WARNING - Less than 80% of the genes in Gpbp1l1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:42,501 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp770 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:42,611 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp748 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:43,038 - pyscenic.transform - WARNING - Less than 80% of the genes in Grhl1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:43,562 - pyscenic.transform - WARNING - Less than 80% of the genes in Ing3 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:43,627 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp759 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:43,648 - pyscenic.transform - WARNING - Less than 80% of the genes in Id4 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:43,757 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp777 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:44,189 - pyscenic.transform - WARNING - Less than 80% of the genes in Ing4 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:44,396 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp780b could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:44,644 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp760 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:45,036 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp784 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:45,623 - pyscenic.transform - WARNING - Less than 80% of the genes in Insm2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:45,762 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp790 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:45,872 - pyscenic.transform - WARNING - Less than 80% of the genes in Grhpr could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:45,969 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp770 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:46,255 - pyscenic.transform - WARNING - Less than 80% of the genes in Irx1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:46,859 - pyscenic.transform - WARNING - Less than 80% of the genes in Gpam could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:46,944 - pyscenic.transform - WARNING - Less than 80% of the genes in Irx2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:47,254 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp777 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:47,582 - pyscenic.transform - WARNING - Less than 80% of the genes in Irx3 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:47,892 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp780b could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:47,925 - pyscenic.transform - WARNING - Less than 80% of the genes in Gpbp1l1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:48,388 - pyscenic.transform - WARNING - Less than 80% of the genes in Irx5 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:48,919 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp784 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:48,956 - pyscenic.transform - WARNING - Less than 80% of the genes in Grhl1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:49,056 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp820 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:49,570 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp790 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:49,711 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp821 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:50,935 - pyscenic.transform - WARNING - Less than 80% of the genes in Patz1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:51,183 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp825 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:51,471 - pyscenic.transform - WARNING - Less than 80% of the genes in Ilf2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:52,089 - pyscenic.transform - WARNING - Less than 80% of the genes in Grhpr could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:52,478 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp830 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:53,298 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp821 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:53,476 - pyscenic.transform - WARNING - Less than 80% of the genes in Ing3 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:53,653 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp84 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:53,789 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf2a2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:53,929 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp825 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:54,419 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf2b could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:54,599 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp830 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:54,770 - pyscenic.transform - WARNING - Less than 80% of the genes in Ivd could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:55,046 - pyscenic.transform - WARNING - Less than 80% of the genes in Ing4 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:55,091 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf2f1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:55,247 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp84 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:55,331 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf2b could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:55,727 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf2h3 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:55,962 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf2f1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:56,708 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf2h3 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:56,781 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp850 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:57,154 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp850 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:57,164 - pyscenic.transform - WARNING - Less than 80% of the genes in Insm2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:57,745 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf3a could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:58,142 - pyscenic.transform - WARNING - Less than 80% of the genes in Irx1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:58,445 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf3c2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:58,462 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp868 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:58,838 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp868 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:59,073 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtpbp1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:59,078 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp869 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:59,173 - pyscenic.transform - WARNING - Less than 80% of the genes in Irx2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:59,704 - pyscenic.transform - WARNING - Less than 80% of the genes in Gzf1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:23:59,877 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp869 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:00,730 - pyscenic.transform - WARNING - Less than 80% of the genes in Irx3 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:01,222 - pyscenic.transform - WARNING - Less than 80% of the genes in Kat7 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:01,433 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp871 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:01,794 - pyscenic.transform - WARNING - Less than 80% of the genes in Irx5 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:01,828 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm2a could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:02,378 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf3a could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:02,443 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm2b could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:02,542 - pyscenic.transform - WARNING - Less than 80% of the genes in Hbp1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:03,019 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtf3c2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:03,091 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm4a could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:03,663 - pyscenic.transform - WARNING - Less than 80% of the genes in Gtpbp1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:03,793 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm4b could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:04,175 - pyscenic.transform - WARNING - Less than 80% of the genes in Patz1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:04,274 - pyscenic.transform - WARNING - Less than 80% of the genes in Gzf1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:04,411 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm4c could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:05,161 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm5a could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:06,695 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp937 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:06,733 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp871 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:07,695 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp942 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:08,428 - pyscenic.transform - WARNING - Less than 80% of the genes in Hbp1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:09,291 - pyscenic.transform - WARNING - Less than 80% of the genes in Hdac3 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:09,386 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp937 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:09,980 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp942 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:10,538 - pyscenic.transform - WARNING - Less than 80% of the genes in Hdac8 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:10,550 - pyscenic.transform - WARNING - Less than 80% of the genes in Ivd could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:11,187 - pyscenic.transform - WARNING - Less than 80% of the genes in Hdx could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:11,781 - pyscenic.transform - WARNING - Less than 80% of the genes in Klf3 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:11,975 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp945 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:13,388 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp949 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:13,832 - pyscenic.transform - WARNING - Less than 80% of the genes in Hdac3 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:13,866 - pyscenic.transform - WARNING - Less than 80% of the genes in Hey1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:14,554 - pyscenic.transform - WARNING - Less than 80% of the genes in Hey2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:14,621 - pyscenic.transform - WARNING - Less than 80% of the genes in Kat7 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:15,583 - pyscenic.transform - WARNING - Less than 80% of the genes in Heyl could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:15,615 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm2a could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:15,934 - pyscenic.transform - WARNING - Less than 80% of the genes in Hdac8 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:16,060 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp945 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:16,152 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp955b could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:16,223 - pyscenic.transform - WARNING - Less than 80% of the genes in Hhat could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:16,622 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm2b could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:16,875 - pyscenic.transform - WARNING - Less than 80% of the genes in Hic2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:17,032 - pyscenic.transform - WARNING - Less than 80% of the genes in Hdx could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:17,500 - pyscenic.transform - WARNING - Less than 80% of the genes in Hif1a could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:17,514 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp961 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:17,656 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm4a could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:18,143 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp949 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:18,641 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm4b could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:18,768 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp976 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:18,772 - pyscenic.transform - WARNING - Less than 80% of the genes in Hirip3 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:19,431 - pyscenic.transform - WARNING - Less than 80% of the genes in Hist2h2ab could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:19,448 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp992 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:19,623 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm4c could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:20,076 - pyscenic.transform - WARNING - Less than 80% of the genes in Hivep1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:20,202 - pyscenic.transform - WARNING - Less than 80% of the genes in Klf6 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:20,635 - pyscenic.transform - WARNING - Less than 80% of the genes in Kdm5a could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:20,702 - pyscenic.transform - WARNING - Less than 80% of the genes in Hivep2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:20,706 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfpm1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:21,025 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Drap1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:21,027 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp955b could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:21,423 - pyscenic.transform - WARNING - Less than 80% of the genes in Hivep3 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:21,472 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfx could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:22,043 - pyscenic.transform - WARNING - Less than 80% of the genes in Hlcs could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:22,078 - pyscenic.transform - WARNING - Less than 80% of the genes in Zgpat could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:22,284 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp961 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:22,760 - pyscenic.transform - WARNING - Less than 80% of the genes in Zhx1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:23,394 - pyscenic.transform - WARNING - Less than 80% of the genes in Zhx2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:23,587 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp976 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:24,228 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp992 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:24,545 - pyscenic.transform - WARNING - Less than 80% of the genes in Zik1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:25,480 - pyscenic.transform - WARNING - Less than 80% of the genes in Hey1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:25,529 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfpm1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:26,041 - pyscenic.transform - WARNING - Less than 80% of the genes in Zkscan1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:26,153 - pyscenic.transform - WARNING - Less than 80% of the genes in Hey2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:26,174 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfx could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:26,696 - pyscenic.transform - WARNING - Less than 80% of the genes in Klf3 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:26,815 - pyscenic.transform - WARNING - Less than 80% of the genes in Zgpat could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:26,820 - pyscenic.transform - WARNING - Less than 80% of the genes in Heyl could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:27,425 - pyscenic.transform - WARNING - Less than 80% of the genes in Hhat could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:27,448 - pyscenic.transform - WARNING - Less than 80% of the genes in Zhx1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:27,579 - pyscenic.transform - WARNING - Less than 80% of the genes in Zkscan3 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:28,092 - pyscenic.transform - WARNING - Less than 80% of the genes in Hic2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:28,188 - pyscenic.transform - WARNING - Less than 80% of the genes in Zhx2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:28,757 - pyscenic.transform - WARNING - Less than 80% of the genes in Hif1a could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:28,759 - pyscenic.transform - WARNING - Less than 80% of the genes in Hmbox1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:28,819 - pyscenic.transform - WARNING - Less than 80% of the genes in Zik1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:29,479 - pyscenic.transform - WARNING - Less than 80% of the genes in Zkscan1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:29,584 - pyscenic.transform - WARNING - Less than 80% of the genes in Kmt2b could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:30,247 - pyscenic.transform - WARNING - Less than 80% of the genes in Zkscan3 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:30,499 - pyscenic.transform - WARNING - Less than 80% of the genes in Hirip3 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:30,601 - pyscenic.transform - WARNING - Less than 80% of the genes in Larp1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:31,551 - pyscenic.transform - WARNING - Less than 80% of the genes in Hist2h2ab could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:31,597 - pyscenic.transform - WARNING - Less than 80% of the genes in Larp4 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:31,737 - pyscenic.transform - WARNING - Less than 80% of the genes in Hmga1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:32,275 - pyscenic.transform - WARNING - Less than 80% of the genes in Zkscan8 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:32,583 - pyscenic.transform - WARNING - Less than 80% of the genes in Hivep1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:32,596 - pyscenic.transform - WARNING - Less than 80% of the genes in Las1l could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:24:33,637 - pyscenic.transform - WARNING - Less than 80% of the genes in Hivep2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# ...
#
# 2025-08-16 20:38:28,510 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(6): Done.
#
# 2025-08-16 20:38:28,881 - pyscenic.transform - WARNING - Less than 80% of the genes in Foxk1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:29,175 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp692 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:30,463 - pyscenic.transform - WARNING - Less than 80% of the genes in Foxm1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:31,159 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp706 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:31,696 - pyscenic.transform - WARNING - Less than 80% of the genes in Foxn2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:31,869 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp707 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:32,523 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp710 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:33,106 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp711 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:33,273 - pyscenic.transform - WARNING - Less than 80% of the genes in Foxo1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:34,384 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp729a could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:34,632 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Prdm15 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:34,829 - pyscenic.transform - WARNING - Less than 80% of the genes in Foxo4 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:36,458 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): All regulons derived.
#
# 2025-08-16 20:38:36,458 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): All regulons derived.
#
# 2025-08-16 20:38:36,505 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): Done.
#
# 2025-08-16 20:38:36,505 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): Done.
#
# 2025-08-16 20:38:39,314 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp740 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:39,897 - pyscenic.transform - WARNING - Less than 80% of the genes in Zfp746 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:39,961 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): All regulons derived.
#
# 2025-08-16 20:38:39,961 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): All regulons derived.
#
# 2025-08-16 20:38:39,972 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): Done.
#
# 2025-08-16 20:38:39,972 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(8): Done.
#
# 2025-08-16 20:38:42,757 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): All regulons derived.
#
# 2025-08-16 20:38:42,757 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): All regulons derived.
#
# 2025-08-16 20:38:42,788 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): Done.
#
# 2025-08-16 20:38:42,788 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): Done.
#
# 2025-08-16 20:38:43,430 - pyscenic.transform - WARNING - Less than 80% of the genes in Gabpb1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:45,466 - pyscenic.transform - WARNING - Less than 80% of the genes in Gata3 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:46,016 - pyscenic.transform - WARNING - Less than 80% of the genes in Gatad1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:47,913 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): All regulons derived.
#
# 2025-08-16 20:38:47,913 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): All regulons derived.
#
# 2025-08-16 20:38:47,930 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): Done.
#
# 2025-08-16 20:38:47,930 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(4): Done.
#
# 2025-08-16 20:38:51,809 - pyscenic.transform - WARNING - Less than 80% of the genes in Git2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:55,801 - pyscenic.transform - WARNING - Less than 80% of the genes in Gm10053 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:56,359 - pyscenic.transform - WARNING - Less than 80% of the genes in Gm13212 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:59,188 - pyscenic.transform - WARNING - Less than 80% of the genes in Gm17655 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:38:59,767 - pyscenic.transform - WARNING - Less than 80% of the genes in Gm2000 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:00,858 - pyscenic.transform - WARNING - Less than 80% of the genes in Gm38394 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:01,418 - pyscenic.transform - WARNING - Less than 80% of the genes in Gm45871 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:01,965 - pyscenic.transform - WARNING - Less than 80% of the genes in Gm4924 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:02,520 - pyscenic.transform - WARNING - Less than 80% of the genes in Gm7072 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:03,097 - pyscenic.transform - WARNING - Less than 80% of the genes in Gm9833 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:04,018 - pyscenic.transform - WARNING - Less than 80% of the genes in Gmeb1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:04,083 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): All regulons derived.
#
# 2025-08-16 20:39:04,083 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): All regulons derived.
#
# 2025-08-16 20:39:04,094 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): Done.
#
# 2025-08-16 20:39:04,094 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(7): Done.
#
# 2025-08-16 20:39:14,445 - pyscenic.transform - WARNING - Less than 80% of the genes in Nfya could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:19,825 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Pou6f1 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:29,164 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Prdm15 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:34,093 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): All regulons derived.
#
# 2025-08-16 20:39:34,093 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): All regulons derived.
#
# 2025-08-16 20:39:34,184 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): Done.
#
# 2025-08-16 20:39:34,184 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(2): Done.
#
# 2025-08-16 20:39:42,092 - pyscenic.transform - WARNING - Less than 80% of the genes in Nuak2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:43,155 - pyscenic.transform - WARNING - Less than 80% of the genes in Nup107 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:39:45,579 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-08-16 20:39:45,579 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-08-16 20:39:45,606 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-08-16 20:39:45,606 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-08-16 20:40:00,019 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Pou6f1 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:40:03,758 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Rbm8a2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:40:15,876 - pyscenic.transform - WARNING - Less than 80% of the genes in Nuak2 could be mapped to mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:40:20,012 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-08-16 20:40:20,012 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): All regulons derived.
#
# 2025-08-16 20:40:20,086 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-08-16 20:40:20,086 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(9): Done.
#
# 2025-08-16 20:40:31,424 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): All regulons derived.
#
# 2025-08-16 20:40:31,424 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): All regulons derived.
#
# 2025-08-16 20:40:31,492 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): Done.
#
# 2025-08-16 20:40:31,492 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): Done.
#
# 2025-08-16 20:40:46,070 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for Rbm8a2 could be mapped to mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings. Skipping this module.
#
# 2025-08-16 20:41:03,757 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): All regulons derived.
#
# 2025-08-16 20:41:03,757 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): All regulons derived.
#
# 2025-08-16 20:41:03,763 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): Done.
#
# 2025-08-16 20:41:03,763 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): Done.
#
# 2025-08-16 20:41:07,448 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): All regulons derived.
#
# 2025-08-16 20:41:07,448 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): All regulons derived.
#
# 2025-08-16 20:41:07,504 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): Done.
#
# 2025-08-16 20:41:07,504 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): Done.
#
# 2025-08-16 20:41:11,071 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): All regulons derived.
#
# 2025-08-16 20:41:11,071 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): All regulons derived.
#
# 2025-08-16 20:41:11,101 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): Done.
#
# 2025-08-16 20:41:11,101 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(3): Done.
#
# 2025-08-16 20:41:51,926 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): All regulons derived.
#
# 2025-08-16 20:41:51,926 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): All regulons derived.
#
# 2025-08-16 20:41:51,934 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): Done.
#
# 2025-08-16 20:41:51,934 - pyscenic.prune - INFO - Worker mm10_500bp_up_100bp_down_full_tx_v10_clust.genes_vs_motifs.rankings(5): Done.
#
# 2025-08-16 20:42:05,106 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): All regulons derived.
#
# 2025-08-16 20:42:05,106 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): All regulons derived.
#
# 2025-08-16 20:42:05,241 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): Done.
#
# 2025-08-16 20:42:05,241 - pyscenic.prune - INFO - Worker mm10_10kbp_up_10kbp_down_full_tx_v10_clust.genes_vs_motifs.rankings(1): Done.
#
# 2025-08-16 20:42:05,411 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %%
# !/home/julia/miniconda3/envs/scenicplus/bin/pyscenic aucell \
    /home/julia/data/placodes/ANDYs_notebboks/Placodes_tragectory/Scenic_otic/placodes_filtered_scenic.loom \
    /home/julia/data/placodes/ANDYs_notebboks/Placodes_tragectory/Scenic_otic/reg_01_07.csv \
    --output /home/julia/data/placodes/ANDYs_notebboks/Placodes_tragectory/Scenic_otic/RPE_mel_pyscenic_output.loom \
    --num_workers 20
# Out:
# 2025-08-16 20:42:13,304 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2025-08-16 20:42:15,288 - pyscenic.cli.pyscenic - INFO - Loading gene signatures.
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []
#
# 2025-08-16 20:42:17,969 - pyscenic.cli.pyscenic - INFO - Calculating cellular enrichment.
#
# 2025-08-16 20:42:35,688 - pyscenic.cli.pyscenic - INFO - Writing results to file.
# /home/julia/miniconda3/envs/scenicplus/lib/python3.8/site-packages/pyscenic/cli/utils.py:347: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, threshold in auc_thresholds.iteritems()
